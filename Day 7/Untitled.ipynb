# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

# %%
df = pd.read_csv('COVID-INFLUENZA-PNEUOMINIA.csv')
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_17848\1088595562.py:1: DtypeWarning: Columns (19,20,21,22,24,25) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('COVID-INFLUENZA-PNEUOMINIA.csv')
