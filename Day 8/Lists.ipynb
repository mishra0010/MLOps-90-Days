# %% [markdown]
# # Lists

# %%
l1 = [1,2,3,4,5]

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
type(l1)
# Out:
# list

# %%
l1[0]
# Out:
# 1

# %%
l1[0:3]
# Out:
# [1, 2, 3]

# %%
l2 = [1, "a", 1.2]

# %%
l2
# Out:
# [1, 'a', 1.2]

# %%
type(l2[0])
# Out:
# int

# %%
type(l2[1])
# Out:
# str

# %%
l3 = [l2, 1, 3]

# %%
l3
# Out:
# [[1, 'a', 1.2], 1, 3]

# %%
type(l3[0])
# Out:
# list

# %%
type(l3[1])
# Out:
# int

# %%
l3[0][1]
# Out:
# 'a'

# %%
list(range(0,10,2))
# Out:
# [0, 2, 4, 6, 8]

# %%
l4 = list(range(0,10,2))

# %%
l4
# Out:
# [0, 2, 4, 6, 8]

# %%
l4.sort(reverse = True)

# %%
l4
# Out:
# [8, 6, 4, 2, 0]

# %%
l4.append(10)

# %%
l4
# Out:
# [8, 6, 4, 2, 0, 10]

# %%
l4[0] = 3

# %%
l4
# Out:
# [3, 6, 4, 2, 0, 10]

# %%
l4.insert(0,15)

# %%
l4
# Out:
# [15, 3, 6, 4, 2, 0, 10]

# %%
l4.remove(3)

# %%
l4
# Out:
# [15, 6, 4, 2, 0, 10]

# %%
del l4[0]

# %%
l4
# Out:
# [6, 4, 2, 0, 10]
