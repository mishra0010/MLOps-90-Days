# %%
str1 = "st python tutorial"

# %%
str1
# Out:
# 'st python tutorial'

# %%
print(str1)
# Out:
# st python tutorial

# %%
x = "R"

# %%
print("st {} tutorial".format(x))
# Out:
# st R tutorial

# %%
x ="SQL"

# %%
print("st {} tutorial".format(x))
# Out:
# st SQL tutorial

# %%
len(str1)
# Out:
# 18

# %%
str1
# Out:
# 'st python tutorial'

# %%
str1.replace("python","r")
# Out:
# 'st r tutorial'

# %%
x[0]
# Out:
# 'S'

# %%
x
# Out:
# 'SQL'

# %%
x[2:6]
# Out:
# 'L'

# %%
type(x)
# Out:
# str
