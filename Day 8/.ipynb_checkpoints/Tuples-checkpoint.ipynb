# %% [markdown]
# # Tuples

# %%
t1 = (1,2)

# %%
t1
# Out:
# (1, 2)

# %%
t1[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 t1[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
type(t1)
# Out:
# tuple
